# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install vit-pytorch
# !pip install timm
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.7/23.7 MB 38.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.6/823.6 kB 62.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.1/14.1 MB 47.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 731.7/731.7 MB 871.3 kB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 410.6/410.6 MB 1.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 121.6/121.6 MB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.5/56.5 MB 1.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 124.2/124.2 MB 2.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 196.0/196.0 MB 2.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 166.0/166.0 MB 1.5 MB/s eta 0:00:00
# ...

# %%
# %cd /content/drive/MyDrive/pneumonia_detection
# Out:
# /content/drive/.shortcut-targets-by-id/1C9Mw4g7yQExYjVXu94z9dYeRxvCAiQ27/pneumonia_detection

# %%
# !python training_main.py \
    --lr 0.0001 \
    --epochs 20 \
    --batch_size 64 \
    --base_model_name "resnet18" \
    --checkpoint_file /content/drive/MyDrive/pneumonia_detection/saved_model/resnet_18.pth \
    --results_dir /content/drive/MyDrive/pneumonia_detection/saved_result/ \
    --images_dir /content/drive/MyDrive/pneumonia_detection/3-kinds-of-pneumonia/Curated-X-Ray-Dataset
# Out:
# 2024-03-24 09:52:03.764730: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-24 09:52:03.764780: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-24 09:52:03.766134: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-24 09:52:05.000088: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Train length 6445
# Test length 1841
# valid length 922
#
# Epoch [1/20] Train Loss: 0.5038
#
# Epoch [1/20] Validation Loss: 0.3748, Accuracy : 0.8406
# Validation loss decreased (inf --> 0.374811).  Saving model ...
#
# ...

# %%
# !python testing_main.py \
    --batch_size 1 \
    --base_model_name "resnet18" \
    --checkpoint_file saved_model/resnet_18.pth \
    --results_dir saved_result/ \
    --images_dir 3-kinds-of-pneumonia/Curated-X-Ray-Dataset
# Out:
# 2024-03-24 11:35:09.245855: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-24 11:35:09.245913: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-24 11:35:09.247300: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-24 11:35:10.436688: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Downloading: "https://download.pytorch.org/models/resnet18-f37072fd.pth" to /root/.cache/torch/hub/checkpoints/resnet18-f37072fd.pth
# 100% 44.7M/44.7M [00:00<00:00, 113MB/s]
# Model Loaded Successfully
# Test length 1841
# ...

# %%
# !python training_main.py \
    --lr 0.0001 \
    --epochs 20 \
    --batch_size 64 \
    --base_model_name "resnet50" \
    --checkpoint_file /content/drive/MyDrive/pneumonia_detection/saved_model/resnet_50.pth \
    --results_dir /content/drive/MyDrive/pneumonia_detection/saved_result/ \
    --images_dir /content/drive/MyDrive/pneumonia_detection/3-kinds-of-pneumonia/Curated-X-Ray-Dataset
# Out:
# 2024-03-24 16:45:24.678155: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-24 16:45:24.678223: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-24 16:45:24.679594: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-24 16:45:25.892034: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
# 100% 97.8M/97.8M [00:00<00:00, 136MB/s]
# Train length 6445
# Test length 1841
# ...

# %%
# !python testing_main.py \
    --batch_size 1 \
    --base_model_name "resnet50" \
    --checkpoint_file saved_model/resnet_50.pth \
    --results_dir saved_result/ \
    --images_dir 3-kinds-of-pneumonia/Curated-X-Ray-Dataset

# %%
# !python training_main.py \
    --lr 0.0001 \
    --epochs 40 \
    --batch_size 4 \
    --base_model_name "vit_l_16" \
    --checkpoint_file /content/drive/MyDrive/pneumonia_detection/saved_model/vit_l_16_train_test_val.pth \
    --results_dir /content/drive/MyDrive/pneumonia_detection/saved_result/ \
    --train_images_dir /content/drive/MyDrive/pneumonia_detection/3-kinds-of-pneumonia/train \
    --valid_images_dir /content/drive/MyDrive/pneumonia_detection/3-kinds-of-pneumonia/validation

# %%
# !python testing_main.py \
    --batch_size 1 \
    --base_model_name "vit_l_16" \
    --checkpoint_file /content/drive/MyDrive/pneumonia_detection/saved_model/vit_l_16_train_test_val.pth \
    --results_dir saved_result/ \
    --images_dir 3-kinds-of-pneumonia/test
# Out:
# 2024-03-31 13:56:16.707812: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-03-31 13:56:16.707864: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-03-31 13:56:16.709148: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-03-31 13:56:17.906977: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# Model Loaded Successfully
# Test length 1842
# Predicting:  53% 979/1842 [05:55<04:41,  3.07it/s]

# %%
# !python training_main.py \
    --lr 0.001 \
    --epochs 40 \
    --batch_size 4 \
    --base_model_name "vit_32_simpleViT" \
    --checkpoint_file /content/drive/MyDrive/pneumonia_detection/saved_model/vit_32_simplevit_train_test_val.pthh \
    --results_dir /content/drive/MyDrive/pneumonia_detection/saved_result/ \
    --train_images_dir /content/drive/MyDrive/pneumonia_detection/3-kinds-of-pneumonia/train \
    --valid_images_dir /content/drive/MyDrive/pneumonia_detection/3-kinds-of-pneumonia/validation

# %%
# !python testing_main.py \
    --batch_size 4 \
    --base_model_name "vit_32_simpleViT" \
    --checkpoint_file /content/drive/MyDrive/pneumonia_detection/saved_model/vit_32_simplevit_train_test_val.pth \
    --results_dir /content/drive/MyDrive/pneumonia_detection/saved_result/ \
    --images_dir 3-kinds-of-pneumonia/test
